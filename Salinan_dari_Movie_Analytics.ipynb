# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

pd.set_option('display.max_columns', None)
sns.set_context('notebook')
sns.set_style('whitegrid')
sns.set_palette('Spectral')

import warnings
warnings.filterwarnings('ignore')

# %%
os.chdir("/content/gdrive/MyDrive/csv")

# %%
os.listdir()
# Out:
# ['ratings_small.csv', 'movies_metadata.csv']

# %%
movies_data = pd.read_csv("movies_metadata.csv")

# %%
movies_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45463 entries, 0 to 45462
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   adult                  45463 non-null  bool
#  1   belongs_to_collection  4491 non-null   object
#  2   budget                 45463 non-null  int64
#  3   genres                 45463 non-null  object
#  4   homepage               7779 non-null   object
#  5   id                     45463 non-null  int64
#  6   imdb_id                45446 non-null  object
#  7   original_language      45452 non-null  object
#  8   original_title         45463 non-null  object
#  9   overview               44509 non-null  object
#  10  popularity             45460 non-null  float64
#  11  poster_path            45077 non-null  object
#  12  production_companies   45460 non-null  object
#  13  production_countries   45460 non-null  object
#  14  release_date           45376 non-null  object
#  15  revenue                45460 non-null  float64
#  16  runtime                45203 non-null  float64
#  17  spoken_languages       45460 non-null  object
#  18  status                 45379 non-null  object
#  19  tagline                20412 non-null  object
#  20  title                  45460 non-null  object
#  21  video                  45463 non-null  bool
#  22  vote_average           45460 non-null  float64
#  23  vote_count             45460 non-null  float64
# dtypes: bool(2), float64(5), int64(2), object(15)
# memory usage: 7.7+ MB

# %%
movies_data.sample(10)
# Out:
#        adult                              belongs_to_collection   budget  \
# 19270   True                                                NaN        0
# 27275   True                                                NaN        0
# 21284   True                                                NaN        0
# 5733    True                                                NaN        0
# 26880   True                                                NaN        0
# 40457   True                                                NaN        0
# 1790    True                                                NaN        0
# 4267    True  {'id': 421566, 'name': 'Totò Collection', 'pos...        0
# 4772    True                                                NaN  4500000
# 35383   True                                                NaN        0
#
#                                                   genres  \
# 19270  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
# 27275  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
# 21284  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 5733                                                  []
# 26880                     [{'id': 35, 'name': 'Comedy'}]
# 40457                [{'id': 99, 'name': 'Documentary'}]
# 1790   [{'id': 18, 'name': 'Drama'}, {'id': 12, 'name...
# 4267   [{'id': 80, 'name': 'Crime'}, {'id': 35, 'name...
# 4772   [{'id': 14, 'name': 'Fantasy'}, {'id': 18, 'na...
# 35383  [{'id': 14, 'name': 'Fantasy'}, {'id': 10751, ...
#
#                             homepage      id    imdb_id original_language  \
# 19270                            NaN   85414  tt1990181                en
# 27275                            NaN   39042  tt0984210                en
# 21284                            NaN   39308  tt0062150                en
# 5733                             NaN  277724  tt0230252                en
# 26880                            NaN   53571  tt0022254                en
# 40457  http://fortheloveofspock.com/  338544  tt4572820                en
# 1790                             NaN   60951  tt0125980                en
# 4267                             NaN   24382  tt0052216                it
# 4772                             NaN    1433  tt0256009                es
# 35383                            NaN   79720  tt0138074                en
#
#                       original_title  \
# 19270                          Brake
# 27275              Multiple Sarcasms
# 21284                    Slave Girls
# 5733             Better Housekeeping
# 26880       Parlor, Bedroom and Bath
# 40457          For the Love of Spock
# 1790           Passion in the Desert
# 4267                 I soliti ignoti
# 4772          El espinazo del diablo
# 35383  Santa and the Ice Cream Bunny
#
#                                                 overview  popularity  \
# 19270  A Secret Service Agent is held captive in the ...    9.213358
# 27275  Gabriel is a man who on the surface has it all...    0.332584
# 21284  Leader of a tribe of amazon women, Queen Kari,...    1.018994
# 5733   Follows the escalation of hostilities between ...    0.003312
# 26880  Jeffrey Haywood wants to marry to Virginia Emb...    0.122557
# 40457  A documentary film about the life of Star Trek...    3.087962
# 1790   Young French officer Augustin Robert escorts a...    0.396851
# 4267   Peppe, formerly a boxer, organizes the break-i...    6.035008
# 4772   After losing his father, 10-year-old Carlos ar...   11.111299
# 35383  Poor Santa Claus. This live-action feature fin...    0.142255
#
#                             poster_path  \
# 19270  /i6sJzILrDowLSo97lPXxPdj8jSi.jpg
# 27275  /aFCzbkgMdEsNtBNzkJ1lMBwB8gc.jpg
# 21284  /j8BErNYPmchtMGS1EztlrVLoFbO.jpg
# 5733                                NaN
# 26880  /iCEveSl8ISt124CNOzZZQukohDf.jpg
# 40457  /inya59isiVecLxNDRBAz1WYFieY.jpg
# 1790   /xD5LNTEYxcyZaSdSWBcJLATCOJF.jpg
# 4267   /x09KfYUEBHoO2QB7KHtYGpVdxtj.jpg
# 4772   /e9UizPFgoCnRCPtR0tyg2JNXY6A.jpg
# 35383  /w8rBP1E3U7BHmm45GxOyOMxZeL1.jpg
#
#                                     production_companies  \
# 19270  [{'name': 'Lightning Entertainment', 'id': 325...
# 27275  [{'name': 'Multiple Avenue Releasing', 'id': 5...
# 21284  [{'name': 'Hammer Film Productions', 'id': 131...
# 5733                                                  []
# 26880                                                 []
# 40457                [{'name': '455 Films', 'id': 7525}]
# 1790   [{'name': 'Fine Line Features', 'id': 8}, {'na...
# 4267                  [{'name': 'Lux Vide', 'id': 1082}]
# 4772   [{'name': 'Producciones Anhelo', 'id': 1102}, ...
# 35383  [{'name': 'R & S Film Enterprises Inc.', 'id':...
#
#                                     production_countries release_date  \
# 19270  [{'iso_3166_1': 'US', 'name': 'United States o...   2012-03-22
# 27275  [{'iso_3166_1': 'US', 'name': 'United States o...   2010-05-07
# 21284   [{'iso_3166_1': 'GB', 'name': 'United Kingdom'}]   1967-02-25
# 5733   [{'iso_3166_1': 'US', 'name': 'United States o...   2000-11-11
# 26880                                                 []   1931-02-28
# 40457  [{'iso_3166_1': 'CA', 'name': 'Canada'}, {'iso...   2016-09-09
# 1790   [{'iso_3166_1': 'US', 'name': 'United States o...   1997-08-31
# 4267             [{'iso_3166_1': 'IT', 'name': 'Italy'}]   1958-06-06
# 4772   [{'iso_3166_1': 'ES', 'name': 'Spain'}, {'iso_...   2001-04-20
# 35383  [{'iso_3166_1': 'US', 'name': 'United States o...   1972-01-01
#
#          revenue  runtime                           spoken_languages  \
# 19270        0.0     92.0   [{'iso_639_1': 'en', 'name': 'English'}]
# 27275        0.0     97.0   [{'iso_639_1': 'en', 'name': 'English'}]
# 21284        0.0     90.0   [{'iso_639_1': 'en', 'name': 'English'}]
# 5733         0.0     90.0   [{'iso_639_1': 'en', 'name': 'English'}]
# 26880        0.0     73.0                                         []
# 40457        0.0    105.0   [{'iso_639_1': 'en', 'name': 'English'}]
# 1790         0.0     91.0   [{'iso_639_1': 'en', 'name': 'English'}]
# 4267         0.0    106.0  [{'iso_639_1': 'it', 'name': 'Italiano'}]
# 4772   6459020.0    106.0   [{'iso_639_1': 'es', 'name': 'Español'}]
# 35383        0.0     96.0   [{'iso_639_1': 'en', 'name': 'English'}]
#
#          status                                            tagline  \
# 19270  Released                     The only way out is to give in
# 27275  Released                                                NaN
# 21284  Released  Beaten into submission . . . turned into slave...
# 5733   Released                                                NaN
# 26880  Released                                                NaN
# 40457  Released                                       Live long...
# 1790   Released            What nature divides, the spirit unites.
# 4267   Released                                                NaN
# 4772   Released  The living will always be more dangerous than ...
# 35383  Released  The amazing story of Santa in big trouble... A...
#
#                                title  video  vote_average  vote_count
# 19270                          Brake  False           5.3        75.0
# 27275              Multiple Sarcasms  False           6.3         2.0
# 21284                    Slave Girls  False           5.1         5.0
# 5733             Better Housekeeping  False           0.0         0.0
# 26880       Parlor, Bedroom and Bath  False           2.5         2.0
# 40457          For the Love of Spock  False           7.8        48.0
# 1790           Passion in the Desert  False           5.8         5.0
# 4267      Big Deal on Madonna Street  False           8.1       107.0
# 4772            The Devil's Backbone  False           7.2       277.0
# 35383  Santa and the Ice Cream Bunny  False           2.3         4.0

# %%
movies_data["release_date"] = pd.to_datetime(movies_data["release_date"])

# %%
movies_data["release_date"].dtypes
# Out:
# dtype('<M8[ns]')

# %%
movies_data["status"].unique()
# Out:
# array(['Released', nan, 'Rumored', 'Post Production', 'In Production',
#        'Planned', 'Canceled'], dtype=object)

# %%
movies_data["original_language"].nunique()
# Out:
# 89

# %%
#movies_data["status"] == "Released"

# %%
movies_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45463 entries, 0 to 45462
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   adult                  45463 non-null  bool
#  1   belongs_to_collection  4491 non-null   object
#  2   budget                 45463 non-null  int64
#  3   genres                 45463 non-null  object
#  4   homepage               7779 non-null   object
#  5   id                     45463 non-null  int64
#  6   imdb_id                45446 non-null  object
#  7   original_language      45452 non-null  object
#  8   original_title         45463 non-null  object
#  9   overview               44509 non-null  object
#  10  popularity             45460 non-null  float64
#  11  poster_path            45077 non-null  object
#  12  production_companies   45460 non-null  object
#  13  production_countries   45460 non-null  object
#  14  release_date           45376 non-null  datetime64[ns]
#  15  revenue                45460 non-null  float64
#  16  runtime                45203 non-null  float64
#  17  spoken_languages       45460 non-null  object
#  18  status                 45379 non-null  object
#  19  tagline                20412 non-null  object
#  20  title                  45460 non-null  object
#  21  video                  45463 non-null  bool
#  22  vote_average           45460 non-null  float64
#  23  vote_count             45460 non-null  float64
# dtypes: bool(2), datetime64[ns](1), float64(5), int64(2), object(14)
# memory usage: 7.7+ MB

# %%
movies_data.head()
# Out:
#    adult                              belongs_to_collection    budget  \
# 0   True  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1   True                                                NaN  65000000
# 2   True  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3   True                                                NaN  16000000
# 4   True  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# 1                                   NaN   8844  tt0113497                en
# 2                                   NaN  15602  tt0113228                en
# 3                                   NaN  31357  tt0114885                en
# 4                                   NaN  11862  tt0113041                en
#
#                 original_title  \
# 0                    Toy Story
# 1                      Jumanji
# 2             Grumpier Old Men
# 3            Waiting to Exhale
# 4  Father of the Bride Part II
#
#                                             overview  popularity  \
# 0  Led by Woody, Andy's toys live happily in his ...   21.946943
# 1  When siblings Judy and Peter discover an encha...   17.015539
# 2  A family wedding reignites the ancient feud be...   11.712900
# 3  Cheated on, mistreated and stepped on, the wom...    3.859495
# 4  Just when George Banks has recovered from his ...    8.387519
#
#                         poster_path  \
# 0  /rhIRbceoE9lR4veEXuwCC2wARtG.jpg
# 1  /vzmL6fP7aPKNKPRTFnZmiUfciyV.jpg
# 2  /6ksm1sjKMFLbO7UY2i6G1ju9SML.jpg
# 3  /16XOMpEaLWkrcPqSQqhTmeJuqQl.jpg
# 4  /e64sOI48hQXyru7naBFyssKFxVd.jpg
#
#                                 production_companies  \
# 0     [{'name': 'Pixar Animation Studios', 'id': 3}]
# 1  [{'name': 'TriStar Pictures', 'id': 559}, {'na...
# 2  [{'name': 'Warner Bros.', 'id': 6194}, {'name'...
# 3  [{'name': 'Twentieth Century Fox Film Corporat...
# 4  [{'name': 'Sandollar Productions', 'id': 5842}...
#
#                                 production_countries release_date  \
# 0  [{'iso_3166_1': 'US', 'name': 'United States o...   1995-10-30
# 1  [{'iso_3166_1': 'US', 'name': 'United States o...   1995-12-15
# 2  [{'iso_3166_1': 'US', 'name': 'United States o...   1995-12-22
# 3  [{'iso_3166_1': 'US', 'name': 'United States o...   1995-12-22
# 4  [{'iso_3166_1': 'US', 'name': 'United States o...   1995-02-10
#
#        revenue  runtime                                   spoken_languages  \
# 0  373554033.0     81.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 1  262797249.0    104.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 2          0.0    101.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 3   81452156.0    127.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 4   76578911.0    106.0           [{'iso_639_1': 'en', 'name': 'English'}]
#
#      status                                            tagline  \
# 0  Released                                                NaN
# 1  Released          Roll the dice and unleash the excitement!
# 2  Released  Still Yelling. Still Fighting. Still Ready for...
# 3  Released  Friends are the people who let you be yourself...
# 4  Released  Just When His World Is Back To Normal... He's ...
#
#                          title  video  vote_average  vote_count
# 0                    Toy Story  False           7.7      5415.0
# 1                      Jumanji  False           6.9      2413.0
# 2             Grumpier Old Men  False           6.5        92.0
# 3            Waiting to Exhale  False           6.1        34.0
# 4  Father of the Bride Part II  False           5.7       173.0

# %%
movies_data["profit"] = movies_data["revenue"] - movies_data["budget"]

# %%
movies_data["profit"].hist(bins = 100)
plt.title("Profit Movies Distribution")
plt.show()

# %%
movies_data["profit"].describe()
# Out:
# count    4.546000e+04
# mean     6.984491e+06
# std      5.214125e+07
# min     -1.657101e+08
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      0.000000e+00
# max      2.550965e+09
# Name: profit, dtype: float64

# %%
import seaborn as sns

# %%
movies_data["profit"].plot(kind = "box")
# Out:
# <Axes: >

# %%
sns.boxplot(data = movies_data, x = "profit")
plt.show()

# %%
sns.boxplot(data = movies_data, x = "runtime")
plt.show()

# %%
movies_data["profit"].quantile(0.9)
# Out:
# 1578210.8999999824

# %%
sns.scatterplot(data = movies_data,
                x = "runtime",
                y = "profit")
plt.show()

# %%
profitable_movies = movies_data[movies_data["profit"] > 0]

# %%
sns.scatterplot(data = profitable_movies,
                x = "runtime",
                y = "profit")
plt.show()

# %%
rating = pd.read_csv("ratings_small.csv")

# %%
rating_movies = rating.groupby("movieId", as_index = False)["rating"].median()

# %%
sns.histplot(data = rating_movies,
                x = "rating")
# Out:
# <Axes: xlabel='rating', ylabel='Count'>

# %%
rating_movies["good_movies"] = rating_movies["rating"] >= 3

# %%
rating_movies["good_movies"].value_counts().plot(kind = "pie")
# Out:
# <Axes: ylabel='good_movies'>

# %%
new_df = movies_data.merge(rating_movies,
                        left_on = "id",
                        right_on = "movieId",
                        how = "inner")

# %%
sns.histplot(data = new_df,
             x = "profit",
             hue = "good_movies")
# Out:
# <Axes: xlabel='profit', ylabel='Count'>

# %%
sns.scatterplot(data = new_df,
             x = "rating",
                y = "profit")
# Out:
# <Axes: xlabel='rating', ylabel='profit'>

# %%
new_df[["rating"]]
# Out:
#       rating
# 0       3.75
# 1       1.50
# 2       4.00
# 3       3.50
# 4       5.00
# ...      ...
# 2826    3.25
# 2827    4.00
# 2828    4.00
# 2829    4.00
# 2830    5.00
#
# [2831 rows x 1 columns]

# %%
new_df["original_language"].value_counts().plot(kind = "bar")
# Out:
# <Axes: >

# %%
new_df.select_dtypes(include = "number")
# Out:
#         budget     id  popularity      revenue  runtime  vote_average  \
# 0     60000000    949   17.924927  187436818.0    170.0           7.7
# 1     58000000    710   14.686036  352194034.0    130.0           6.6
# 2     98000000   1408    7.284477   10017322.0    119.0           5.7
# 3     52000000    524   10.137389  116112375.0    178.0           7.8
# 4     16500000   4584   10.673167  135000000.0    136.0           7.2
# ...        ...    ...         ...          ...      ...           ...
# 2826         0  80831    0.083371          0.0    121.0           6.5
# 2827         0   3104    2.302582          0.0     92.0           5.9
# 2828         0  64197    0.528657          0.0     97.0           6.0
# 2829         0  98604    0.803588          0.0     91.0           4.6
# 2830         0  49280    1.109068          0.0      1.0           6.5
#
#       vote_count       profit  movieId  rating
# 0         1886.0  127436818.0      949    3.75
# 1         1194.0  294194034.0      710    1.50
# 2          137.0  -87982678.0     1408    4.00
# 3         1343.0   64112375.0      524    3.50
# 4          364.0  118500000.0     4584    5.00
# ...          ...          ...      ...     ...
# 2826         2.0          0.0    80831    3.25
# 2827        33.0          0.0     3104    4.00
# 2828         5.0          0.0    64197    4.00
# 2829         6.0          0.0    98604    4.00
# 2830        22.0          0.0    49280    5.00
#
# [2831 rows x 10 columns]

# %%
def select_columns(df: pd.DataFrame, features: list,  target: list = "rating"):

  df = df.dropna().reset_index(drop = True)
  X = df[features]
  y = (df[target] >= 3).astype("int")

  return X, y

# %%
from sklearn.model_selection import train_test_split

# %%
features = ["budget", "popularity", "vote_average"]
X, y = select_columns(new_df, features = features)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 42)

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
minmax = MinMaxScaler()

# %%
minmax.fit(X_train)
# Out:
# MinMaxScaler()

# %%
def scaling(df, scaler):

  # df["runtime	"] = df["runtime"].div(60)

  scaled_array = scaler.transform(df)
  scaled_df = pd.DataFrame(scaled_array, columns = scaler.get_feature_names_out())

  return scaled_df

# %%
X_train_scaled = scaling(X_train, minmax)
X_test_scaled = scaling(X_test, minmax)

# %%
X_test_scaled.iloc[0]
# Out:
# budget          0.500000
# popularity      0.042270
# vote_average    0.568182
# Name: 0, dtype: float64

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier

# %%
knn = KNeighborsClassifier(n_neighbors = 5)
dt = DecisionTreeClassifier()

# %%
knn.fit(X_train_scaled, y_train)
dt.fit(X_train_scaled, y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_train_pred_knn = knn.predict(X_train_scaled)
y_train_pred_dt = dt.predict(X_train_scaled)

# %%
y_test_pred_knn = knn.predict(X_test_scaled)
y_test_pred_dt = dt.predict(X_test_scaled)

# %%
pd.crosstab(y_test, y_test_pred_knn)
# Out:
# col_0   0   1
# rating
# 0       0   6
# 1       1  35

# %%
pd.crosstab(y_test, y_test_pred_dt)
# Out:
# col_0   0   1
# rating
# 0       1   5
# 1       3  33
